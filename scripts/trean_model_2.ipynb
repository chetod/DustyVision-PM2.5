# %%
# !pip install pycaret

# %%
from pycaret.time_series import TSForecastingExperiment
import pandas as pd
data = pd.read_csv(r'C:\Users\ASUS\Desktop\projectforecastpm2_5\dataforecast\cleandata_v1_day.csv')

# %%
s = TSForecastingExperiment()
s.setup(data, fh=7, fold=5, session_id=123, target="pm_2_5")
# Out:
# <style type="text/css">
# #T_3d28c_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d28c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d28c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3d28c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d28c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d28c_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_3d28c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3d28c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d28c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d28c_row1_col1" class="data row1 col1" >pm_2_5</td>
#     </tr>
#     <tr>
#       <th id="T_3d28c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = s.compare_models()
# Out:
# <style type="text/css">
# #T_5b565 th {
#   text-align: left;
# }
# ...

# %%
tune_model1 = s.tune_model(best)
# Out:
# <style type="text/css">
# #T_fc774_row5_col0, #T_fc774_row5_col1, #T_fc774_row5_col2, #T_fc774_row5_col3, #T_fc774_row5_col4, #T_fc774_row5_col5, #T_fc774_row5_col6, #T_fc774_row5_col7 {
#   background: yellow;
# }
# </style>
# <table id="T_fc774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc774_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_fc774_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_fc774_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_fc774_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_fc774_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_fc774_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_fc774_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_fc774_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
x = s.predict_model(best)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = s.predict_model(best)
#
# NameError: name 's' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 s.evaluate_model(model)
#
# File c:\Users\ASUS\Desktop\projectforecastpm2_5\.venv\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2133, in _TabularExperiment.evaluate_model(self, estimator, fold, fit_kwargs, plot_kwargs, feature_name, groups)
#    2129 fold = self._get_cv_splitter(fold)
#    2131 groups = self._get_groups(groups)
# -> 2133 interact(
#    2134     self._plot_model,
#    2135     estimator=fixed(estimator),
#    2136     plot=a,
#    2137     save=fixed(False),
#    2138     verbose=fixed(False),
#    2139     scale=fixed(1),
#    2140     fold=fixed(fold),
#    2141     fit_kwargs=fixed(fit_kwargs),
#    2142     plot_kwargs=fixed(plot_kwargs),
#    2143     feature_name=fixed(feature_name),
#    2144     label=fixed(False),
# ...

# %%
# Import necessary libraries
from pycaret.regression import *
import pandas as pd
import numpy as np

# Assuming your data is already loaded as 'data' with target column
data = pd.read_csv(r'C:\Users\ASUS\Desktop\projectforecastpm2_5\dataforecast\cleandata_vtest_hours.csv')

# Initialize setup
s = setup(data, target = 'pm_2_5', session_id = 123, 
          train_size = 0.7, normalize = True,
          polynomial_features = True, 
           bin_numeric_features = None,
          ignore_features = None)

best = compare_models()
# Out:
# <style type="text/css">
# #T_751b7_row9_col1, #T_751b7_row15_col1, #T_751b7_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_751b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_751b7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_751b7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_751b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_751b7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_751b7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_751b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_751b7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_751b7_row1_col1" class="data row1 col1" >pm_2_5</td>
#     </tr>
#     <tr>
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
